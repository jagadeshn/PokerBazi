# %%
import cv2
import matplotlib

# %%
import numpy as np

# %%
path = r"C:\Users\jagadesh\Desktop\cards\z1extra\all"

# %%
for i in path:
    src = cv2.imread(path)

# %%
src = cv2.imread(r"C:/Users/jagadesh/Desktop/cards/z1extra/all/10c.JPG")
target_size = (64,64)
dst = cv2.resize(src, target_size)

# %%
dst = dst.reshape(target_size.shape[0] * target_size.shape[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-288728d7a111> in <module>
# ----> 1 dst = dst.reshape(target_size.shape[0] * target_size.shape[1])
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
dst
# Out:
# array([[[ 75,  57,  73],
#         [ 74,  71,  65],
#         [ 56,  76,  47],
#         ...,
#         [ 60,  65,  68],
#         [ 72,  70,  76],
#         [ 68,  68,  69]],
#
#        [[ 69,  68,  72],
#         [ 52,  67,  46],
#         [ 65, 106,  58],
#         ...,
#         [ 60,  72,  60],
#         [ 65,  69,  66],
#         [ 68,  68,  68]],
#
#        [[ 57,  75,  65],
#         [ 50,  89,  50],
#         [ 81, 149,  76],
#         ...,
#         [ 80, 106,  74],
#         [ 60,  71,  55],
#         [ 65,  66,  65]],
#
#        ...,
#
#        [[ 72,  70,  70],
#         [ 35,  96,  36],
#         [ 12, 125,  13],
#         ...,
#         [ 56, 102,  56],
#         [ 59,  74,  67],
#         [ 65,  67,  66]],
#
#        [[ 80,  70,  76],
#         [ 39,  86,  38],
#         [ 15, 112,  17],
#         ...,
#         [ 52,  77,  62],
#         [ 61,  63,  80],
#         [ 71,  72,  75]],
#
#        [[ 83,  74,  72],
#         [ 63,  71,  63],
#         [ 46,  78,  54],
# ...

# %%
from PIL import Image
# %matplotlib inline

# %%
image = Image.open(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards\2s\2s.jpg")

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=101x135 at 0x258B9828438>

# %%
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (101, 135)
# RGB

# %%
load_image.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e218fec9f17a> in <module>
# ----> 1 load_image.show()
#
# NameError: name 'load_image' is not defined

# %%
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = Image.open(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards\2s\2s.jpg")
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f9339d496d1f> in <module>
#       4 image = Image.open(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards\2s\2s.jpg")
#       5 # summarize shape of the pixel array
# ----> 6 print(image.dtype)
#       7 print(image.shape)
#       8 # display the array of pixels as an image
#
# AttributeError: 'JpegImageFile' object has no attribute 'dtype'

# %%
i = Image.open(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards\2s\2s.jpg")
iar = np.asarray(i)

# %%
print(iar)
# Out:
# [[[73 73 73]
#   [69 69 69]
#   [68 68 68]
#   ...
#   [71 71 71]
#   [73 73 73]
#   [73 73 73]]
#
#  [[75 75 75]
#   [71 71 71]
#   [69 69 69]
#   ...
#   [72 72 72]
#   [75 75 75]
#   [75 75 75]]
#
#  [[76 76 76]
#   [73 73 73]
#   [71 71 71]
#   ...
#   [72 72 72]
#   [76 76 76]
#   [76 76 76]]
#
#  ...
#
#  [[72 72 72]
#   [66 66 66]
#   [68 68 68]
#   ...
#   [67 67 67]
#   [65 65 65]
#   [63 63 63]]
#
#  [[70 70 70]
#   [67 67 67]
#   [70 70 70]
#   ...
#   [66 66 66]
#   [66 66 66]
#   [66 66 66]]
#
#  [[69 69 69]
#   [64 64 64]
#   [67 67 67]
#   ...
#   [70 70 70]
#   [72 72 72]
#   [73 73 73]]]

# %%
im = image.convert('L')

im
# Out:
# <PIL.Image.Image image mode=L size=98x130 at 0x1F4FC39CE80>

# %%
array(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c6624f6dcb44> in <module>
# ----> 1 array(im)
#
# NameError: name 'array' is not defined

# %%
imahee = cv2.imread(r"C:/Users/jagadesh/Desktop/cards/z1extra/all/10c.JPG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d649c26b5f13> in <module>
#       1 imahee = cv2.imread(r"C:/Users/jagadesh/Desktop/cards/z1extra/all/10c.JPG")
# ----> 2 b = dec2bin(I)
#
# NameError: name 'dec2bin' is not defined

# %%
print(imahee)
# Out:
# None
