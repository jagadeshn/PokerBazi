# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
from resizeimage import resizeimage

# %%
#read image from file location
image = imread('C:/Users/jagadesh/Pictures/cards/2c/2c.JPG', as_gray=True)
#display image
imshow(image)

# %%
#Resize image
with open('C:/Users/jagadesh/Pictures/cards/2c/2c.JPG', 'rb') as f:
    with Image.open(f) as image:
        cover = resizeimage.resize_cover(image, [200, 100])
        cover.save('test-image-cover.jpeg', image.format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9bb707802c13> in <module>
#       1 #Resize image
#       2 with open('C:/Users/jagadesh/Pictures/cards/2c/2c.JPG', 'rb') as f:
# ----> 3     with Image.open(f) as image:
#       4         cover = resizeimage.resize_cover(image, [200, 100])
#       5         cover.save('test-image-cover.jpeg', image.format)
#
# NameError: name 'Image' is not defined

# %%
imshow(image)
