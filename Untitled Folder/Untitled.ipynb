# %%
# import tensorflow.keras.layers as Layers
# import tensorflow.keras.activations as Actications
# import tensorflow.keras.models as Models
# import tensorflow.keras.optimizers as Optimizer
# import tensorflow.keras.metrics as Metrics
# import tensorflow.keras.utils as Utils
# from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %%
def get_images(directory):
    Images = []
    Labels = [] 
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'glacier': #Folder contain Glacier Images get the '2' class label.
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
        
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(64,64)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

# %%
X = get_images(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards/")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-d411efcf60b4> in <module>
# ----> 1 X = get_images(r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards/")
#
# <ipython-input-2-dbe4b82311f3> in get_images(directory)
#      20         for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
#      21             image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
# ---> 22             image = cv2.resize(image,(64,64)) #Resize the image, Some images are different sizes. (Resizing is very Important)
#      23             Images.append(image)
#      24             Labels.append(label)
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:4044: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
import tensorflow as tf

# %%
directory = r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards"
tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
)
# Out:
# Found 265 files belonging to 53 classes.
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os

# %%
directory1 = r"C:\Users\jagadesh\Jupyter Projects\PokerBazi\cards"
directory2 =r"C:\Users\jagadesh\Pictures\new_cards"

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=(256, 256),
    batch_size=32,
)
# Out:
# Found 265 files belonging to 53 classes.
# Using 212 files for training.

# %%
image_size = (32, 32)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 265 files belonging to 53 classes.
# Using 212 files for training.
# Found 265 files belonging to 53 classes.
# Using 53 files for validation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
print(type(train_ds))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %%
image_size = (32, 32)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)
    activation = "softmax"
    units = num_classes
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 100

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# WARNING:tensorflow:Automatic model reloading for interrupted job was removed from the `ModelCheckpoint` callback in multi-worker mode, please use the `keras.callbacks.experimental.BackupAndRestore` callback instead. See this tutorial for details: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_keras#backupandrestore_callback.
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# 7/7 [==============================] - ETA: 0s - loss: -2674.6675 - accuracy: 0.0142WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# 7/7 [==============================] - 2s 304ms/step - loss: -2674.6675 - accuracy: 0.0142 - val_loss: -26.3491 - val_accuracy: 0.0189
# Epoch 2/100
# 7/7 [==============================] - 2s 247ms/step - loss: -2940.8000 - accuracy: 0.0142 - val_loss: -23.6319 - val_accuracy: 0.0189
# Epoch 3/100
# 7/7 [==============================] - 2s 259ms/step - loss: -3003.8096 - accuracy: 0.0142 - val_loss: -15.9775 - val_accuracy: 0.0189
# Epoch 4/100
# 7/7 [==============================] - 2s 258ms/step - loss: -3288.7605 - accuracy: 0.0142 - val_loss: -9.3670 - val_accuracy: 0.0189
# Epoch 5/100
# 7/7 [==============================] - 4s 534ms/step - loss: -3505.7551 - accuracy: 0.0142 - val_loss: -6.4837 - val_accuracy: 0.0189
# Epoch 6/100
# 7/7 [==============================] - 4s 574ms/step - loss: -3782.8491 - accuracy: 0.0142 - val_loss: -6.4927 - val_accuracy: 0.0189
# Epoch 7/100
# 7/7 [==============================] - 2s 250ms/step - loss: -3888.3503 - accuracy: 0.0142 - val_loss: -6.8643 - val_accuracy: 0.0189
# Epoch 8/100
# 7/7 [==============================] - 2s 253ms/step - loss: -4227.3057 - accuracy: 0.0142 - val_loss: -6.9916 - val_accuracy: 0.0189
# Epoch 9/100
# 7/7 [==============================] - 2s 252ms/step - loss: -4501.9580 - accuracy: 0.0142 - val_loss: -7.3086 - val_accuracy: 0.0189
# Epoch 10/100
# 7/7 [==============================] - 2s 251ms/step - loss: -4704.9277 - accuracy: 0.0142 - val_loss: -7.5616 - val_accuracy: 0.0189
# Epoch 11/100
# 7/7 [==============================] - 2s 248ms/step - loss: -4934.4351 - accuracy: 0.0142 - val_loss: -8.2555 - val_accuracy: 0.0189
# Epoch 12/100
# 7/7 [==============================] - 2s 261ms/step - loss: -5127.4868 - accuracy: 0.0142 - val_loss: -8.7968 - val_accuracy: 0.0189
# Epoch 13/100
# 7/7 [==============================] - 2s 253ms/step - loss: -5462.4014 - accuracy: 0.0142 - val_loss: -9.3336 - val_accuracy: 0.0189
# Epoch 14/100
# 7/7 [==============================] - 2s 267ms/step - loss: -50371.8320 - accuracy: 0.0142 - val_loss: -77211.5547 - val_accuracy: 0.0189
# Epoch 89/100
# 7/7 [==============================] - 2s 269ms/step - loss: -51289.4727 - accuracy: 0.0142 - val_loss: -66346.8672 - val_accuracy: 0.0189
# Epoch 90/100
# 7/7 [==============================] - 2s 255ms/step - loss: -52543.6289 - accuracy: 0.0142 - val_loss: -73032.7891 - val_accuracy: 0.0189
# Epoch 91/100
# 7/7 [==============================] - 2s 245ms/step - loss: -53017.4922 - accuracy: 0.0142 - val_loss: -79249.5859 - val_accuracy: 0.0189
# Epoch 92/100
# 7/7 [==============================] - 2s 254ms/step - loss: -53221.3359 - accuracy: 0.0142 - val_loss: -117943.5312 - val_accuracy: 0.0189
# Epoch 93/100
# 7/7 [==============================] - 2s 262ms/step - loss: -55112.4453 - accuracy: 0.0142 - val_loss: -135920.9062 - val_accuracy: 0.0189
# Epoch 94/100
# 7/7 [==============================] - 2s 249ms/step - loss: -55713.9336 - accuracy: 0.0142 - val_loss: -101902.1484 - val_accuracy: 0.0189
# Epoch 95/100
# 7/7 [==============================] - 2s 247ms/step - loss: -57829.8828 - accuracy: 0.0142 - val_loss: -84639.9062 - val_accuracy: 0.0189
# Epoch 96/100
# 7/7 [==============================] - 2s 271ms/step - loss: -57747.5742 - accuracy: 0.0142 - val_loss: -98202.7656 - val_accuracy: 0.0189
# Epoch 97/100
# 7/7 [==============================] - 2s 253ms/step - loss: -59506.6133 - accuracy: 0.0142 - val_loss: -115433.8359 - val_accuracy: 0.0189
# Epoch 98/100
# 7/7 [==============================] - 2s 248ms/step - loss: -60475.6641 - accuracy: 0.0142 - val_loss: -83054.9922 - val_accuracy: 0.0189
# Epoch 99/100
# 7/7 [==============================] - 2s 247ms/step - loss: -60822.3164 - accuracy: 0.0142 - val_loss: -121780.7344 - val_accuracy: 0.0189
# Epoch 100/100
# 7/7 [==============================] - 2s 253ms/step - loss: -62372.0664 - accuracy: 0.0142 - val_loss: -112392.9141 - val_accuracy: 0.0189

# %%
image_size = (32, 32)
batch_size = 32

train1_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory2,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val1_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory2,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 62 files belonging to 2 classes.
# Using 50 files for training.
# Found 62 files belonging to 2 classes.
# Using 12 files for validation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train1_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
epochs = 5

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train1_ds, epochs=epochs, callbacks=callbacks, validation_data=val1_ds,
)
# Out:
# WARNING:tensorflow:Automatic model reloading for interrupted job was removed from the `ModelCheckpoint` callback in multi-worker mode, please use the `keras.callbacks.experimental.BackupAndRestore` callback instead. See this tutorial for details: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_keras#backupandrestore_callback.
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# 2/2 [==============================] - ETA: 0s - loss: 2.4060 - accuracy: 0.8400WARNING:tensorflow:Model was constructed with shape (None, 180, 180, 3) for input Tensor("input_3:0", shape=(None, 180, 180, 3), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# 2/2 [==============================] - 1s 378ms/step - loss: 2.4060 - accuracy: 0.8400 - val_loss: 2.6461 - val_accuracy: 0.3333
# Epoch 2/5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.8441 - accuracy: 0.8600 - val_loss: 2.6390 - val_accuracy: 0.3333
# Epoch 3/5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.2052 - accuracy: 0.8800 - val_loss: 2.5537 - val_accuracy: 0.3333
# Epoch 4/5
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 2.4622 - val_accuracy: 0.3333
# Epoch 5/5
# 2/2 [==============================] - 0s 202ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 2.3555 - val_accuracy: 0.3333

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    #x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    #x = layers.BatchNormalization()(x)
    #x = layers.Activation("relu")(x)
    x = layers.Dense(17,activation="relu")
    # x = layers.BatchNormalization()(x)
    #x = layers.Activation("relu")(x)
    #x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    #x = layers.Activation("relu")(x)
    #x = layers.GlobalAveragePooling2D()(x)
    activation = "softmax"
    units = num_classes
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

model = make_model(input_shape=image_size + (3,), num_classes=52)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-284857f59769> in <module>
#      21     return keras.Model(inputs, outputs)
#      22
# ---> 23 model = make_model(input_shape=image_size + (3,), num_classes=52)
#      24 keras.utils.plot_model(model, show_shapes=True)
#
# <ipython-input-66-284857f59769> in make_model(input_shape, num_classes)
#      17     activation = "softmax"
#      18     units = num_classes
# ---> 19     x = layers.Dropout(0.5)(x)
#      20     outputs = layers.Dense(units, activation=activation)(x)
#      21     return keras.Model(inputs, outputs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     977
#     978         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 979           outputs = call_fn(inputs, *args, **kwargs)
#     980
#     981         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\layers\core.py in call(self, inputs, training)
#     216     output = tf_utils.smart_cond(training,
#     217                                  dropped_inputs,
# --> 218                                  lambda: array_ops.identity(inputs))
#     219     return output
#     220
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\utils\tf_utils.py in smart_cond(pred, true_fn, false_fn, name)
#      63         pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      64   return smart_module.smart_cond(
# ---> 65       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      66
#      67
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      54       return true_fn()
#      55     else:
# ---> 56       return false_fn()
#      57   else:
#      58     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\layers\core.py in <lambda>()
#     216     output = tf_utils.smart_cond(training,
#     217                                  dropped_inputs,
# --> 218                                  lambda: array_ops.identity(inputs))
#     219     return output
#     220
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\array_ops.py in identity(input, name)
#     284     # Make sure we get an input with handle data attached from resource
#     285     # variables. Variables have correct handle data when graph building.
# --> 286     input = ops.convert_to_tensor(input)
#     287   ret = gen_array_ops.identity(input, name=name)
#     288   # Propagate handle data for happier shape inference for resource variables.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1523
#    1524     if ret is None:
# -> 1525       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1526
#    1527     if ret is NotImplemented:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Attempt to convert a value (<tensorflow.python.keras.layers.core.Dense object at 0x000001C018259898>) with an unsupported type (<class 'tensorflow.python.keras.layers.core.Dense'>) to a Tensor.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(53, activation='softmax')
    ])
    
#model = make_model(input_shape=image_size + (3,), num_classes=53)
#keras.utils.plot_model(model, show_shapes=True)

# %%
image_size = (32, 32)
batch_size = 13

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 265 files belonging to 53 classes.
# Using 212 files for training.
# Found 265 files belonging to 53 classes.
# Using 53 files for validation.

# %%
epochs = 3000

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# WARNING:tensorflow:Automatic model reloading for interrupted job was removed from the `ModelCheckpoint` callback in multi-worker mode, please use the `keras.callbacks.experimental.BackupAndRestore` callback instead. See this tutorial for details: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_keras#backupandrestore_callback.
# Epoch 1/3000
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28) for input Tensor("flatten_3_input:0", shape=(None, 28, 28), dtype=float32), but it was called on an input with incompatible shape (None, 32, 32, 3).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-4e965bd3c12f> in <module>
#      10 )
#      11 model.fit(
# ---> 12     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
#      13 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1099                 _r=1):
#    1100               callbacks.on_train_batch_begin(step)
# -> 1101               tmp_logs = train_function(iterator)
#    1102               if data_handler.should_sync:
#    1103                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     784       else:
#     785         compiler = "nonXla"
# --> 786         result = self._call(*args, **kwds)
#     787
#     788       new_tracing_count = self._get_tracing_count()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     827       # This is the first call of __call__, so we have to initialize.
#     828       initializers = []
# --> 829       self._initialize(args, kwds, add_initializers_to=initializers)
#     830     finally:
#     831       # At this point we know that the initialization is complete (or less
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     701     self._concrete_stateful_fn = (
#     702         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 703             *args, **kwds))
#     704
#     705     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2881       args, kwargs = None, None
#    2882     with self._lock:
# -> 2883       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2884     return graph_function
#    2885
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3238
#    3239       self._function_cache.missed.add(call_context_key)
# -> 3240       graph_function = self._create_graph_function(args, kwargs)
#    3241       self._function_cache.primary[cache_key] = graph_function
#    3242       return graph_function, args, kwargs
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3100             arg_names=arg_names,
#    3101             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3102             capture_by_value=self._capture_by_value),
#    3103         self._function_attributes,
#    3104         function_spec=self.function_spec,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     604         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     605         # the function a weak reference to itself to avoid a reference cycle.
# --> 606         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     607     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     608
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py:808 train_function  *
#         return step_function(self, iterator)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py:798 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\distribute\distribute_lib.py:1231 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\distribute\distribute_lib.py:2764 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\distribute\distribute_lib.py:3161 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py:791 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py:749 train_step
#         y_pred = self(x, training=True)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\base_layer.py:979 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\sequential.py:372 call
#         return super(Sequential, self).call(inputs, training=training, mask=mask)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\functional.py:382 call
#         inputs, training=training, mask=mask)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\functional.py:504 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\base_layer.py:970 __call__
#         self.name)
#     C:\Users\jagadesh\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\input_spec.py:223 assert_input_compatibility
#         ' but received input with shape ' + str(shape))
#
#     ValueError: Input 0 of layer dense_10 is incompatible with the layer: expected axis -1 of input shape to have value 784 but received input with shape [None, 3072]

# %%
img = keras.preprocessing.image.load_img(
    r"C:\Users\jagadesh\Pictures\cards\2c\2c.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(predictions)
print(score)
# Out:
# [[0.01912596 0.0186922  0.01884777 0.01869044 0.01881004 0.01873816
#   0.01852425 0.01867347 0.01854895 0.01885446 0.01887124 0.01839822
#   0.01838649 0.01873693 0.01899912 0.01903114 0.01870661 0.01884673
#   0.01866621 0.01927269 0.01890006 0.01862507 0.0190613  0.01863343
#   0.01880255 0.01898475 0.01862298 0.01913723 0.0192342  0.01895059
#   0.01884035 0.01905989 0.01871754 0.01888603 0.01931368 0.01838879
#   0.01910439 0.01890157 0.01848719 0.01905266 0.01887845 0.01880888
#   0.01870454 0.01891512 0.01905082 0.01900928 0.01924629 0.01890852
#   0.01892902 0.01897138 0.01920805 0.0191282  0.0191164 ]]

# %%
# def make_model(input_shape, num_classes):
#     inputs = keras.Input(shape=input_shape)
#     # Image augmentation block
#     x = data_augmentation(inputs)

#     # Entry block
#     x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
#     x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     x = layers.Conv2D(64, 3, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     previous_block_activation = x  # Set aside residual

#     for size in [128, 256, 512, 728]:
#         x = layers.Activation("relu")(x)
#         x = layers.SeparableConv2D(size, 3, padding="same")(x)
#         x = layers.BatchNormalization()(x)

#         x = layers.Activation("relu")(x)
#         x = layers.SeparableConv2D(size, 3, padding="same")(x)
#         x = layers.BatchNormalization()(x)

#         x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

#         # Project residual
#         residual = layers.Conv2D(size, 1, strides=2, padding="same")(
#             previous_block_activation
#         )
#         x = layers.add([x, residual])  # Add back residual
#         previous_block_activation = x  # Set aside next residual

#     x = layers.SeparableConv2D(1024, 3, padding="same")(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     x = layers.GlobalAveragePooling2D()(x)
#     if num_classes == 2:
#         activation = "sigmoid"
#         units = 1
#     else:
#         activation = "softmax"
#         units = num_classes

#     x = layers.Dropout(0.5)(x)
#     outputs = layers.Dense(units, activation=activation)(x)
#     return keras.Model(inputs, outputs)


# model = make_model(input_shape=image_size + (3,), num_classes=2)
# keras.utils.plot_model(model, show_shapes=True)

# %%
image_size = (32, 32)
batch_size = 13

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory1,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(53, activation='softmax')
    ])
