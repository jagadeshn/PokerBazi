# %%
from imageai.Prediction.Custom import ModelTraining
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-9c53ea21e22d> in <module>
# ----> 1 from imageai.Prediction.Custom import ModelTraining
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Prediction\Custom\__init__.py in <module>
#       2 from ..ResNet.resnet50 import ResNet50
#       3 from ..InceptionV3.inceptionv3 import InceptionV3
# ----> 4 from ..DenseNet.densenet import DenseNetImageNet121
#       5 from tensorflow.python.keras.optimizers import Adam
#       6 from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Prediction\DenseNet\densenet.py in <module>
#      19 from tensorflow.python.keras.layers import BatchNormalization
#      20 from tensorflow.python.keras.regularizers import l2
# ---> 21 from tensorflow.python.keras.utils import convert_all_kernels_in_model
#      22 from ..DenseNet.imagenet_utils import _obtain_input_shape
#      23 from ..DenseNet.imagenet_utils import decode_predictions
#
# ImportError: cannot import name 'convert_all_kernels_in_model' from 'tensorflow.python.keras.utils' (C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\python\keras\utils\__init__.py)

# %%
from tensorflow.python.keras.utils import convert_all_kernels_in_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-d9e65da0b63c> in <module>
# ----> 1 from tensorflow.python.keras.utils import convert_all_kernels_in_model
#
# ImportError: cannot import name 'convert_all_kernels_in_model' from 'tensorflow.python.keras.utils' (C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\python\keras\utils\__init__.py)

# %%
from imageai.Prediction.Custom import ModelTraining
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-9c53ea21e22d> in <module>
# ----> 1 from imageai.Prediction.Custom import ModelTraining
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Prediction\Custom\__init__.py in <module>
#       2 from ..ResNet.resnet50 import ResNet50
#       3 from ..InceptionV3.inceptionv3 import InceptionV3
# ----> 4 from ..DenseNet.densenet import DenseNetImageNet121
#       5 from tensorflow.python.keras.optimizers import Adam
#       6 from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Prediction\DenseNet\densenet.py in <module>
#      19 from tensorflow.python.keras.layers import BatchNormalization
#      20 from tensorflow.python.keras.regularizers import l2
# ---> 21 from tensorflow.python.keras.utils import convert_all_kernels_in_model
#      22 from ..DenseNet.imagenet_utils import _obtain_input_shape
#      23 from ..DenseNet.imagenet_utils import decode_predictions
#
# ImportError: cannot import name 'convert_all_kernels_in_model' from 'tensorflow.python.keras.utils' (C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\python\keras\utils\__init__.py)

# %%
from imageai.Detection.Custom import DetectionModelTrainer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3e0f69aa5452> in <module>
# ----> 1 from imageai.Detection.Custom import DetectionModelTrainer
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Detection\__init__.py in <module>
#       1 import cv2
# ----> 2 from imageai.Detection.keras_retinanet.models.resnet import resnet50_retinanet
#       3 from imageai.Detection.keras_retinanet.utils.image import read_image_bgr, read_image_array, read_image_stream, \
#       4     preprocess_image, resize_image
#       5 from imageai.Detection.keras_retinanet.utils.visualization import draw_box, draw_caption
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\imageai\Detection\keras_retinanet\models\resnet.py in <module>
#      17 import warnings
#      18
# ---> 19 import keras
#      20 from imageai.Detection import keras_resnet
#      21 from imageai.Detection.keras_resnet import models
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\keras\__init__.py in <module>
#       2
#       3 from . import utils
# ----> 4 from . import activations
#       5 from . import applications
#       6 from . import backend
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\keras\activations.py in <module>
#       4 from . import backend as K
#       5 from .utils.generic_utils import deserialize_keras_object
# ----> 6 from .engine import Layer
#       7
#       8
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\keras\engine\__init__.py in <module>
#       6 from .topology import Layer
#       7 from .topology import get_source_inputs
# ----> 8 from .training import Model
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\keras\engine\training.py in <module>
#      23 from .. import metrics as metrics_module
#      24 from ..utils.generic_utils import Progbar
# ---> 25 from .. import callbacks as cbks
#      26 from ..legacy import interfaces
#      27
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\keras\callbacks.py in <module>
#      24 if K.backend() == 'tensorflow':
#      25     import tensorflow as tf
# ---> 26     from tensorflow.contrib.tensorboard.plugins import projector
#      27
#      28
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\__init__.py in <module>
#      35 from tensorflow.contrib import copy_graph
#      36 from tensorflow.contrib import crf
# ---> 37 from tensorflow.contrib import cudnn_rnn
#      38 from tensorflow.contrib import data
#      39 from tensorflow.contrib import deprecated
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\cudnn_rnn\__init__.py in <module>
#      36
#      37 # pylint: disable=unused-import,wildcard-import
# ---> 38 from tensorflow.contrib.cudnn_rnn.python.layers import *
#      39 # pylint: enable=unused-import,wildcard-import
#      40
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\layers\__init__.py in <module>
#      21
#      22 # pylint: disable=unused-import,wildcard-import
# ---> 23 from tensorflow.contrib.cudnn_rnn.python.layers.cudnn_rnn import *
#      24 # pylint: enable=unused-import,wildcard-import
#      25
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\layers\cudnn_rnn.py in <module>
#      18 from __future__ import print_function
#      19
# ---> 20 from tensorflow.contrib.cudnn_rnn.python.ops import cudnn_rnn_ops
#      21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import ops
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py in <module>
#      20 import os
#      21 from tensorflow.contrib.checkpoint.python import split_dependency
# ---> 22 from tensorflow.contrib.rnn.python.ops import lstm_ops
#      23 from tensorflow.python.framework import dtypes
#      24 from tensorflow.python.framework import ops
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\rnn\python\ops\lstm_ops.py in <module>
#      22 import six
#      23
# ---> 24 from tensorflow.contrib.rnn.ops import gen_lstm_ops
#      25 from tensorflow.contrib.util import loader
#      26 from tensorflow.python.framework import dtypes
#
# C:\LocalDiskD\ProgrammingRequisites\Anaconda\lib\site-packages\tensorflow\contrib\rnn\ops\gen_lstm_ops.py in <module>
#     194   return _result
#     195
# --> 196 _ops.RegisterShape("BlockLSTM")(None)
#     197
#     198
#
# AttributeError: module 'tensorflow.python.framework.ops' has no attribute 'RegisterShape'
